# %% [markdown]
# ## The anisotropy function and the negative log-likelihood plots.

# %%
from I3Tray import *
from icecube import icetray, dataclasses, phys_services, sim_services, dataio,  earthmodel_service, neutrino_generator, tableio, hdfwriter
from icecube.simprod import segments
from icecube.icetray import I3Units, I3Frame
from icecube.dataclasses import I3Particle
from icecube.simclasses import I3MMCTrack
from icecube.icetray import I3Units, OMKey, I3Frame
import numpy as np
from matplotlib import pyplot as plt
import numpy as np
import sys, os
import math
from os import path
from scipy import stats
from scipy.stats import norm
import scipy.special as sp

# %% [markdown]
# ### Cascade fitter (after implementing anisotropy):

# %%
def frame_absent(run_num):
    if (run_num==6 or run_num==14 or run_num==36 or run_num==41 or run_num==49 or run_num==54 or run_num==59 or run_num==61 or run_num==76 or run_num==80 or run_num==82 or run_num==106 or run_num==131 or run_num==133 
        or run_num==149 or run_num==155 or run_num==172 or run_num==176 or run_num==189 or run_num==193 or run_num==198 or run_num==208 or run_num==214 or run_num==216
        or run_num==223 or run_num==226 or run_num==235 or run_num==238 or run_num==252 or run_num==284 or run_num==288 or run_num==311 or run_num==369 or run_num==371 or run_num==377 or run_num==379 or run_num==378 or run_num==385 or run_num==389 or run_num==390 
        or run_num==391 or run_num==392 or run_num==393 or run_num==397 or run_num==594
        or run_num==395 or run_num==399 or run_num==401 or run_num==403 or run_num==419 or run_num==471 or run_num==521 or run_num==522 or run_num==550 or run_num==538 or run_num==574 or 
        run_num==584 or run_num==569 or run_num==643 or run_num==646 or run_num==647 or run_num==648 
        or run_num==650 or run_num==656 or run_num==657
        or run_num==658 or run_num==659 or run_num==665 or run_num==675 or run_num==683 or run_num==685 or run_num==686 or run_num==708 or run_num==711
        or run_num==714 or run_num==726 or run_num==737 or run_num==835 or run_num==873 or run_num==889 or run_num==746 or run_num==837 or run_num==867 or run_num==878 or run_num==917 or run_num==944 or run_num==949 or run_num==954 or run_num==963 or run_num==971
        or run_num==972 or run_num==895 or run_num==984 or run_num==987 or run_num==988 or run_num==989):
        return True
    else:
        return False

# %%
nloglike_cascade_nue_aniso=[]
nloglike_cascade_nutau_aniso=[]
nloglike_track_numu_aniso=[]
nfitparameters_llhfit=5
nfitparameters_nutau=4
events_nue=0
events_nutau=0
events_numu=0
for i in range(0,975):
    print("File:",i)
    if path.exists("/data/p-one/kdutta/Neutau_anisotropy/Nu_reco"+str(i)+".i3.zst")==True:
        infile_name="/data/p-one/kdutta/Neutau_anisotropy/Nu_reco"+str(i)+".i3.zst"
    if path.exists("/data/p-one/kdutta/Neutau_anisotropy/Nu_reco"+str(i)+".i3.zst")==True:
        infile_name="/data/p-one/kdutta/Neutau_anisotropy/Nu_reco"+str(i)+".i3.zst"
        if(frame_absent(i)==False):           
            infile=dataio.I3File(infile_name)
            infile.pop_frame()
            infile.pop_frame()
            count=0
            for frame in infile:
                count=count+1      #all frames are not working. So will work with a limited number of frames per file.
                if(count<=100):
                    pulses=0
                    pulseseriesmap=frame['I3Photons_PMTResponse']
                    for omkey in pulseseriesmap.keys():
# File: 945
# File: 946
# File: 947
# File: 948
# File: 949
# File: 950
# File: 951
# File: 952
# File: 953
# File: 954
# File: 955
# File: 956
# File: 957
# File: 958
# File: 959
# File: 960
# File: 961
# File: 962
# File: 963
# File: 964
# File: 965
# File: 966
# File: 967
# File: 968
# File: 969
# File: 970
# File: 971
# File: 972
# File: 973
# File: 974
# 958
# 881
# 915

# %%
#plt.hist(nloglike_cascade_nue_aniso, bins=50, histtype='step',label='nue, cascade fit',color='blue')
plt.hist(nloglike_cascade_nutau_aniso, bins=50, histtype='step',label='nutau, cascade fit',color='green')
plt.hist(nloglike_track_numu_aniso, bins=50, histtype='step',label='numu, track fit',color='red')
plt.xlabel('nloglike/(npulses-nfitparameters)',fontsize=12)
plt.ylabel('Number of events',fontsize=12)
plt.title("After adding anisotropy",fontsize=15)
#plt.xlim(-1000,10000)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Cascade fitter (before implementing anisotropy):

# %%
nloglike_cascade_nue=[]
nloglike_cascade_nutau=[]
nloglike_track_numu=[]
nfitparameters_llhfit=5
nfitparameters_nutau=4
events_nue=0
events_nutau=0
events_numu=0
for i in range(0,975):
    print("File",i)
    if path.exists("/data/p-one/kdutta/Neutau_reco/Nu_reco"+str(i)+".i3.zst")==True:
        infile_name="/data/p-one/kdutta/Neutau_reco/Nu_reco"+str(i)+".i3.zst"
        if(frame_absent(i)==False):  
            infile=dataio.I3File(infile_name)
            infile.pop_frame()
            infile.pop_frame()
            count=0
            for frame in infile:
                count=count+1      #all frames are not working. So will work with a limited number of frames per file.
                if(count<=100):
                    #events=events+1
                    pulses=0
                    pulseseriesmap=frame['I3Photons_PMTResponse']
                    for omkey in pulseseriesmap.keys():
                        for pulse in pulseseriesmap[omkey]:
                            pulses=pulses+1
                    if(frame['NuGPrimary'].pdg_encoding==16 or frame['NuGPrimary'].pdg_encoding==-16):
                        events_nutau=events_nutau+1
                        nloglike_cascade_nutau.append((frame['NuTau_nloglike'].value)/(pulses-nfitparameters_nutau))                
                    elif(frame['NuGPrimary'].pdg_encoding==12 or frame['NuGPrimary'].pdg_encoding==-12):
                        events_nue=events_nue+1
                        nloglike_cascade_nue.append((frame['NuTau_nloglike'].value)/(pulses-nfitparameters_nutau))
                    elif(frame['NuGPrimary'].pdg_encoding==14 or frame['NuGPrimary'].pdg_encoding==-14):      
                        events_numu=events_numu+1
                        nloglike_track_numu.append((frame['llhfit_nloglike'].value)/(pulses-nfitparameters_llhfit))
                else:
                    break
    else:
        continue
print(events_nutau)
print(events_nue)
# Out:
# File 0
# File 1
# File 2
# File 3
# File 4
# File 5
# File 6
# File 7
# File 8
# File 9
# File 10
# File 11
# File 12
# File 13
# File 14
# File 15
# File 16
# File 17
# File 18
# File 19
# File 20
# File 21
# File 22
# File 23
# File 24
# File 25
# File 26
# File 27
# File 28
# File 29
# File 30
# File 31
# File 32
# File 33
# File 34
# File 35
# File 36
# File 37
# File 38
# File 39
# File 40
# File 41
# File 42
# File 43
# File 44
# File 45
# File 962
# File 963
# File 964
# File 965
# File 966
# File 967
# File 968
# File 969
# File 970
# File 971
# File 972
# File 973
# File 974
# 958
# 881

# %%
print(events_numu)
# Out:
# 1015

# %%
#plt.hist(nloglike_cascade_nue, bins=75, histtype='step',label='nue, cascade fit',color='blue')
plt.hist(nloglike_cascade_nutau, bins=75, histtype='step',label='nutau, cascade fit',color='green')
plt.hist(nloglike_track_numu, bins=75, histtype='step',label='numu, track fit',color='red')
plt.xlabel('nloglike/(npulses-nfitparameters)',fontsize=12)
plt.ylabel('Number of events',fontsize=12)
plt.title("Before adding anisotropy",fontsize=15)
#plt.xlim(-1000,10000)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Comparison: Before and after adding anisotropy...

# %%
plt.hist(nloglike_cascade_nue_aniso, bins=75, histtype='step',label='nue, after',color='blue')
plt.hist(nloglike_cascade_nue, bins=75, histtype='step',label='nue, before',color='red')
plt.xlabel('nloglike/(npulses-nfitparameters)',fontsize=12)
plt.ylabel('Number of events',fontsize=12)
plt.title("Comparison: Before & After adding anisotropy",fontsize=15)
#plt.xlim(-1000,10000)
plt.legend(loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-50d848f333b6> in <module>
# ----> 1 plt.hist(nloglike_cascade_nue_aniso, bins=75, histtype='step',label='nue, after',color='blue')
#       2 plt.hist(nloglike_cascade_nue, bins=75, histtype='step',label='nue, before',color='red')
#       3 plt.xlabel('nloglike/(npulses-nfitparameters)',fontsize=12)
#       4 plt.ylabel('Number of events',fontsize=12)
#       5 plt.title("Comparison: Before & After adding anisotropy",fontsize=15)
#
# /cvmfs/icecube.opensciencegrid.org/py3-v4.1.1/Ubuntu_20.04_x86_64/lib/python3.7/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3135                       histtype=histtype, align=align, orientation=orientation,
#    3136                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3137                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3138     finally:
#    3139         ax._hold = washold
#
# /cvmfs/icecube.opensciencegrid.org/py3-v4.1.1/Ubuntu_20.04_x86_64/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /cvmfs/icecube.opensciencegrid.org/py3-v4.1.1/Ubuntu_20.04_x86_64/lib/python3.7/site-packages/matplotlib/axes/_axes.py in hist(***failed resolving arguments***)
#    6637             # this will automatically overwrite bins,
#    6638             # so that each histogram uses the same bins
# -> 6639             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6640             m = m.astype(float)  # causes problems later if it's an int
#    6641             if mlast is None:
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# /cvmfs/icecube.opensciencegrid.org/py3-v4.1.1/Ubuntu_20.04_x86_64/lib/python3.7/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     793     a, weights = _ravel_and_check_weights(a, weights)
#     794
# --> 795     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     796
#     797     # Histogram is an integer or a float array depending on the weights.
#
# /cvmfs/icecube.opensciencegrid.org/py3-v4.1.1/Ubuntu_20.04_x86_64/lib/python3.7/site-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     427             raise ValueError('`bins` must be positive, when an integer')
#     428
# --> 429         first_edge, last_edge = _get_outer_edges(a, range)
#     430
#     431     elif np.ndim(bins) == 1:
#
# /cvmfs/icecube.opensciencegrid.org/py3-v4.1.1/Ubuntu_20.04_x86_64/lib/python3.7/site-packages/numpy/lib/histograms.py in _get_outer_edges(a, range)
#     314         if first_edge > last_edge:
#     315             raise ValueError(
# --> 316                 'max must be larger than min in range parameter.')
#     317         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
#     318             raise ValueError(
#
# ValueError: max must be larger than min in range parameter.

# %%
plt.hist(nloglike_cascade_nutau_aniso, bins=75, histtype='step',label='nutau, after',color='blue')
plt.hist(nloglike_cascade_nutau, bins=75, histtype='step',label='nutau, before',color='red')
plt.xlabel('nloglike/(npulses-nfitparameters)',fontsize=12)
plt.ylabel('Number of events',fontsize=12)
plt.title("Comparison: Before & After adding anisotropy",fontsize=15)
#plt.xlim(-1000,10000)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Predictions of the 3 fitters...

# %%
diff_linefit_zenith=[]
diff_llhfit_zenith=[]
diff_cascade_zenith=[]
diff_linefit_azimuth=[]
diff_llhfit_azimuth=[]
diff_cascade_azimuth=[]

for i in range(0,975):
    print("File",i)
    if path.exists("/data/p-one/kdutta/Neutau_anisotropy/Nu_reco"+str(i)+".i3.zst")==True:
        infile_name="/data/p-one/kdutta/Neutau_anisotropy/Nu_reco"+str(i)+".i3.zst"
        if(frame_absent(i)==False):
            infile=dataio.I3File(infile_name)
            infile.pop_frame()
            infile.pop_frame()
            count=0
            for frame in infile:
                count=count+1      #all frames are not working. So will work with a limited number of frames per file.
                if(count<=30):
                    truth_zenith=frame['NuGPrimary'].dir.zenith
                    truth_azimuth=frame['NuGPrimary'].dir.azimuth
                    diff_linefit_zenith.append(truth_zenith-frame['linefit'].dir.zenith)
                    diff_linefit_azimuth.append(truth_azimuth-frame['linefit'].dir.azimuth)
                    diff_llhfit_zenith.append(truth_zenith-frame['llhfit'].dir.zenith)
                    diff_llhfit_azimuth.append(truth_azimuth-frame['llhfit'].dir.azimuth)
                    diff_cascade_zenith.append(truth_zenith-frame['NuTau'].dir.zenith)
                    diff_cascade_azimuth.append(truth_azimuth-frame['NuTau'].dir.azimuth)     

                else:
                    break
    else:
        continue
# Out:
# File 0
# File 1
# File 2
# File 3
# File 4
# File 5
# File 6
# File 7
# File 8
# File 9
# File 10
# File 11
# File 12
# File 13
# File 14
# File 15
# File 16
# File 17
# File 18
# File 19
# File 20
# File 21
# File 22
# File 23
# File 24
# File 25
# File 26
# File 27
# File 28
# File 29
# File 30
# File 31
# File 32
# File 33
# File 34
# File 35
# File 36
# File 37
# File 38
# File 39
# File 40
# File 41
# File 42
# File 958
# File 959
# File 960
# File 961
# File 962
# File 963
# File 964
# File 965
# File 966
# File 967
# File 968
# File 969
# File 970
# File 971
# File 972
# File 973
# File 974

# %%
plt.hist(diff_llhfit_zenith, bins=100, histtype='step',label='llhfit',color='red')
plt.hist(diff_linefit_zenith, bins=100, histtype='step',label='linefit',color='blue')
plt.hist(diff_cascade_zenith, bins=100, histtype='step',label='cascade',color='green')

plt.xlabel('Difference between true and predicted values (radians)',fontsize=12)
plt.ylabel('Number of events',fontsize=12)
plt.title("Zenith angle prediction (all neutrinos)",fontsize=15)
plt.legend(loc='upper left')
plt.show()

# %%
plt.hist(diff_llhfit_azimuth, bins=100, histtype='step',label='llhfit',color='red')
plt.hist(diff_linefit_azimuth, bins=100, histtype='step',label='linefit',color='blue')
plt.hist(diff_cascade_azimuth, bins=100, histtype='step',label='cascade',color='green')

plt.xlabel('Difference between true and predicted values (radians)',fontsize=12)
plt.ylabel('Number of events',fontsize=12)
plt.title("Azimuth angle prediction (all neutrinos)",fontsize=15)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Based on event topology...

# %%
diff_linefit_zenith_cascade=[]
diff_linefit_zenith_track=[]
diff_llhfit_zenith_cascade=[]
diff_llhfit_zenith_track=[]
diff_cascade_zenith_cascade=[]
diff_cascade_zenith_track=[]
diff_linefit_azimuth_cascade=[]
diff_linefit_azimuth_track=[]
diff_llhfit_azimuth_cascade=[]
diff_llhfit_azimuth_track=[]
diff_cascade_azimuth_cascade=[]
diff_cascade_azimuth_track=[]
events_cascade_anis=0
events_track_anis=0

for i in range(0,975):
    #print("File",i)
    if path.exists("/data/p-one/kdutta/Neutau_anisotropy/Nu_reco"+str(i)+".i3.zst")==True:
        infile_name="/data/p-one/kdutta/Neutau_anisotropy/Nu_reco"+str(i)+".i3.zst"
        if(frame_absent(i)==False):           
            infile=dataio.I3File(infile_name)
            infile.pop_frame()
            infile.pop_frame()
            count=0
            for frame in infile:
                count=count+1      #all frames are not working. So will work with a limited number of frames per file.
                if(count<=100):
                    #events=events+1
                    truth_zenith=frame['NuGPrimary'].dir.zenith
                    truth_azimuth=frame['NuGPrimary'].dir.azimuth
                    if(frame['NuGPrimary'].pdg_encoding==16 or frame['NuGPrimary'].pdg_encoding==-16 or frame['NuGPrimary'].pdg_encoding==12 or frame['NuGPrimary'].pdg_encoding==-12):
                        diff_linefit_zenith_cascade.append(truth_zenith-frame['linefit'].dir.zenith)
                        diff_llhfit_zenith_cascade.append(truth_zenith-frame['llhfit'].dir.zenith)
                        diff_cascade_zenith_cascade.append(truth_zenith-frame['NuTau'].dir.zenith)
                        diff_linefit_azimuth_cascade.append(truth_azimuth-frame['linefit'].dir.azimuth)
                        diff_llhfit_azimuth_cascade.append(truth_azimuth-frame['llhfit'].dir.azimuth)
                        diff_cascade_azimuth_cascade.append(truth_azimuth-frame['NuTau'].dir.azimuth)
                        events_cascade_anis=events_cascade_anis+1
                        
                    elif(frame['NuGPrimary'].pdg_encoding==14 or frame['NuGPrimary'].pdg_encoding==-14):
                        diff_linefit_zenith_track.append(truth_zenith-frame['linefit'].dir.zenith)
                        diff_llhfit_zenith_track.append(truth_zenith-frame['llhfit'].dir.zenith)
                        diff_cascade_zenith_track.append(truth_zenith-frame['NuTau'].dir.zenith)
                        diff_linefit_azimuth_track.append(truth_azimuth-frame['linefit'].dir.azimuth)
                        diff_llhfit_azimuth_track.append(truth_azimuth-frame['llhfit'].dir.azimuth)
                        diff_cascade_azimuth_track.append(truth_azimuth-frame['NuTau'].dir.azimuth)  
                        events_track_anis=events_track_anis+1

                else:
                    break
    else:
        continue

# %%
plt.hist(diff_llhfit_azimuth_cascade, bins=100, histtype='step',label='llhfit',color='red')
plt.hist(diff_linefit_azimuth_cascade, bins=100, histtype='step',label='linefit',color='blue')
plt.hist(diff_cascade_azimuth_cascade, bins=100, histtype='step',label='cascade',color='green')

plt.xlabel('Difference between true and predicted values (radians)',fontsize=12)
plt.ylabel('Number of events',fontsize=12)
plt.title("Azimuth angle prediction (cascade-like events)",fontsize=15)
plt.legend(loc='upper left')
plt.show()

plt.hist(diff_llhfit_zenith_cascade, bins=100, histtype='step',label='llhfit',color='red')
plt.hist(diff_linefit_zenith_cascade, bins=100, histtype='step',label='linefit',color='blue')
plt.hist(diff_cascade_zenith_cascade, bins=100, histtype='step',label='cascade',color='green')

plt.xlabel('Difference between true and predicted values (radians)',fontsize=12)
plt.ylabel('Number of events',fontsize=12)
plt.title("Zenith angle prediction (cascade-like events)",fontsize=15)
plt.legend(loc='upper left')
plt.show()

# %%
plt.hist(np.cos(diff_llhfit_azimuth_cascade), bins=100, histtype='step',label='llhfit',color='red')
plt.hist(np.cos(diff_linefit_azimuth_cascade), bins=100, histtype='step',label='linefit',color='blue')
plt.hist(np.cos(diff_cascade_azimuth_cascade), bins=100, histtype='step',label='cascade',color='green')

plt.xlabel('Difference between true and predicted values (radians)',fontsize=12)
plt.ylabel('Number of events',fontsize=12)
plt.title("Azimuth angle prediction (cascade-like events)",fontsize=15)
plt.legend(loc='upper left')
plt.show()

plt.hist(np.cos(diff_llhfit_zenith_cascade), bins=100, histtype='step',label='llhfit',color='red')
plt.hist(np.cos(diff_linefit_zenith_cascade), bins=100, histtype='step',label='linefit',color='blue')
plt.hist(np.cos(diff_cascade_zenith_cascade), bins=100, histtype='step',label='cascade',color='green')

plt.xlabel('Difference between true and predicted values (radians)',fontsize=12)
plt.ylabel('Number of events',fontsize=12)
plt.title("Zenith angle prediction (cascade-like events)",fontsize=15)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### Comparison between the previous and updated Cascade fitter...

# %%
diff_cascade_zenith_cascade_old=[]
diff_cascade_zenith_track_old=[]
diff_cascade_azimuth_cascade_old=[]
diff_cascade_azimuth_track_old=[]
events_cascade=0
events_track=0
for i in range(0,975):
    #print("File",i)
    if path.exists("/data/p-one/kdutta/Neutau_reco/Nu_reco"+str(i)+".i3.zst")==True:
        infile_name="/data/p-one/kdutta/Neutau_reco/Nu_reco"+str(i)+".i3.zst"
        if(frame_absent(i)==False):
            infile=dataio.I3File(infile_name)
            infile.pop_frame()
            infile.pop_frame()
            count=0
            for frame in infile:
                count=count+1      #all frames are not working. So will work with a limited number of frames per file.
                if(count<=100):
                    truth_zenith=frame['NuGPrimary'].dir.zenith
                    truth_azimuth=frame['NuGPrimary'].dir.azimuth
                    if(frame['NuGPrimary'].pdg_encoding==16 or frame['NuGPrimary'].pdg_encoding==-16 or frame['NuGPrimary'].pdg_encoding==12 or frame['NuGPrimary'].pdg_encoding==-12):
                        events_cascade=events_cascade+1
                        diff_cascade_zenith_cascade_old.append(truth_zenith-frame['NuTau'].dir.zenith)
                        diff_cascade_azimuth_cascade_old.append(truth_azimuth-frame['NuTau'].dir.azimuth)
                    elif(frame['NuGPrimary'].pdg_encoding==14 or frame['NuGPrimary'].pdg_encoding==-14):
                        
                        if(events_track==events_track_anis):
                            break
                        else:
                            events_track=events_track+1
                            diff_cascade_zenith_track_old.append(truth_zenith-frame['NuTau'].dir.zenith)
                            diff_cascade_azimuth_track_old.append(truth_azimuth-frame['NuTau'].dir.azimuth)

# %%
plt.hist(diff_cascade_azimuth_cascade_old, bins=100, histtype='step',label='cascade-fitter (without anisotropy)',color='red')
plt.hist(diff_cascade_azimuth_cascade, bins=100, histtype='step',label='cascade-fitter (with anisotropy)',color='green')

plt.xlabel('Difference between true and predicted values (radians)',fontsize=12)
plt.ylabel('Number of events',fontsize=12)
plt.title("Azimuth angle prediction (cascade-like events)",fontsize=15)
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.4))
plt.show()

plt.hist(diff_cascade_zenith_cascade_old, bins=100, histtype='step',label='cascade-fitter (without anisotropy)',color='red')
plt.hist(diff_cascade_zenith_cascade, bins=100, histtype='step',label='cascade-fitter (with anisotropy)',color='green')

plt.xlabel('Difference between true and predicted values (radians)',fontsize=12)
plt.ylabel('Number of events',fontsize=12)
plt.title("Zenith angle prediction (cascade-like events)",fontsize=15)
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.4))
plt.show()

# %%
plt.hist(np.cos(diff_cascade_azimuth_cascade_old), bins=100, histtype='step',label='cascade-fitter (without anisotropy)',color='red')
plt.hist(np.cos(diff_cascade_azimuth_cascade), bins=100, histtype='step',label='cascade-fitter (with anisotropy)',color='green')

plt.xlabel('cos(difference in radians)',fontsize=12)
plt.ylabel('Number of events',fontsize=12)
plt.title("Azimuth angle prediction (cascade-like events)",fontsize=15)
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.4))
plt.show()

plt.hist(np.cos(diff_cascade_zenith_cascade_old), bins=100, histtype='step',label='cascade-fitter (without anisotropy)',color='red')
plt.hist(np.cos(diff_cascade_zenith_cascade), bins=100, histtype='step',label='cascade-fitter (with anisotropy)',color='green')

plt.xlabel('cos(difference in radians)',fontsize=12)
plt.ylabel('Number of events',fontsize=12)
plt.title("Zenith angle prediction (cascade-like events)",fontsize=15)
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.4))
plt.show()
